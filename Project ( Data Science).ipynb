# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1:-

# %%
data=pd.read_csv("pubg - Dr. Darshan Ingle.csv")
data1= data[:50]
data1
# Out:
#                 Id         groupId         matchId  assists  boosts  \
# 0   2f262dd9795e60  78437bcd91d40e  d5db3a49eb2955        0       0
# 1   a32847cf5bf34b  85b7ce5a12e10b  65223f05c7fdb4        0       0
# 2   1b1900a9990396  edf80d6523380a  1cadec4534f30a        0       3
# 3   f589dd03b60bf2  804ab5e5585558  c4a5676dc91604        0       0
# 4   c23c4cc5b78b35  b3e2cd169ed920  cd595700a01bfa        0       0
# 5   fd034582dd4d2e  9b8930aeee086a  6f6e52b15ddf21        0       1
# 6   c60b5633f4dcc8  7c0f817f6627c7  3232c1e0fec04b        0       3
# 7   f0ba8246b6980f  7318b5204462cb  112e9711f86001        0       0
# 8   79c5d5eda1c72e  a85b81198dfc06  ef5fc25e28ffb1        1       4
# 9   94834a28e52abd  bc513cde35fa54  f36a754a9b88f7        1       1
# 10  f051dcc9b0b3ce  d203c0e3d8c321  89a6a8738190b4        0       0
# 11  f02c2f34accf08  22ed911205c815  559dac9580b92a        1       0
# 12  6701c06774d409  cdb79f944d585b  9f3decb5ffba4e        0       0
# ...

# %% [markdown]
# # Q2:-

# %%
dataTypeSeries = data1.dtypes
print('Data type of each column of Dataframe :')
print(dataTypeSeries)
# Out:
# Data type of each column of Dataframe :
# Id                  object
# groupId             object
# matchId             object
# assists              int64
# boosts               int64
# damageDealt        float64
# DBNOs                int64
# headshotKills        int64
# heals                int64
# killPlace            int64
# killPoints           int64
# kills                int64
# killStreaks          int64
# longestKill        float64
# matchDuration        int64
# matchType           object
# maxPlace             int64
# numGroups            int64
# rankPoints           int64
# revives              int64
# rideDistance       float64
# roadKills            int64
# swimDistance       float64
# teamKills            int64
# vehicleDestroys      int64
# walkDistance       float64
# weaponsAcquired      int64
# winPoints            int64
# winPlacePerc       float64
# dtype: object

# %% [markdown]
# # Q3:-

# %%
data1.describe()
# Out:
#         assists     boosts  damageDealt      DBNOs  headshotKills      heals  \
# count  50.00000  50.000000    50.000000  50.000000      50.000000  50.000000
# mean    0.24000   1.160000   149.089200   0.860000       0.260000   1.800000
# std     0.59109   1.833476   167.564996   1.160753       0.527218   2.878492
# min     0.00000   0.000000     0.000000   0.000000       0.000000   0.000000
# 25%     0.00000   0.000000    25.800000   0.000000       0.000000   0.000000
# 50%     0.00000   0.000000   100.000000   0.000000       0.000000   0.000000
# 75%     0.00000   2.000000   200.000000   1.000000       0.000000   2.000000
# max     3.00000   7.000000   638.200000   4.000000       2.000000   9.000000
#
#        killPlace   killPoints    kills  killStreaks  ...   revives  \
# count  50.000000    50.000000  50.0000    50.000000  ...  50.00000
# mean   48.180000   584.820000   1.1400     0.620000  ...   0.26000
# std    29.822393   650.311658   1.7958     0.752953  ...   0.59966
# ...

# %% [markdown]
# # Q4

# %%
data1['kills'].mean()
# Out:
# 1.14

# %% [markdown]
# # Q5

# %%
data1.kills.quantile(0.99)
# Out:
# 7.019999999999996

# %% [markdown]
# # Q6:-

# %%
data.kills.max()
# Out:
# 35

# %% [markdown]
# # Q7:-

# %%
data1.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %% [markdown]
# # Q8:-

# %%
sns.distplot (data1['matchDuration']);

# %% [markdown]
# Most of the duration of matches are between 1250 to 1500.

# %% [markdown]
# # Q9:-

# %%
sns.distplot(data1['walkDistance'])

# %% [markdown]
# Most of the Walke distance are between 0 to 500.

# %% [markdown]
# # Q10:-

# %%
plt.figure()
plt.subplot (2,1,1)
sns.distplot(data1['matchDuration'])
plt.title('Match Duration')



plt.subplot(2,1,2)
sns.distplot(data1['walkDistance'])

# %% [markdown]
# # Q 11:-

# %%
plt.figure()
plt.subplot (1,2,1)
sns.distplot(data1['matchDuration'])
plt.title('Match Duration')



plt.subplot(1,2,2)
sns.distplot(data1['walkDistance'])
plt.title('walk Distance')
# Out:
# Text(0.5, 1.0, 'walk Distance')

# %% [markdown]
# # Q 12:-

# %%
sns.pairplot(data1);

# %% [markdown]
# # Q13:-

# %%
print (data1['matchType'].unique())
a=len(data1['matchType'].unique())
print(a)
# Out:
# ['squad-fpp' 'squad' 'duo-fpp' 'solo-fpp' 'duo' 'solo']
# 6

# %% [markdown]
# # Q14:-

# %%
sns.barplot(x='matchType', y='killPoints' , data = data1);

# %%
In Duo there is more kill points as compare to other match types.

# %% [markdown]
# # Q 15:-

# %%
sns.barplot(x='matchType', y='weaponsAcquired', data = data1);

# %%
In Squad there is most weapons acquired then other.

# %% [markdown]
# # Q16:-

# %%
cat_features=[i for i in data1.columns if data.dtypes[i]=='object']
cat_features
# Out:
# ['Id', 'groupId', 'matchId', 'matchType']

# %% [markdown]
# # Q 17:-

# %%
sns.boxplot(x='matchType', y='winPlacePerc', data = data1);

# %%
In Duo-fpp there is more chances of Winning.

# %% [markdown]
# # Q 18:-

# %%
sns.boxplot(x='matchType', y='matchDuration', data = data1);

# %% [markdown]
# In duo there is more chances of survival.

# %% [markdown]
# # Q19:-

# %%
sns.boxplot(  y='matchType', x='matchDuration', data = data1);

# %% [markdown]
# # Q20:-

# %%
data1=t_set[:50]
x= data1.headshotKills + data1.teamKills + data1.roadKills
data1['Kill'] =x
data1
# Out:
# <ipython-input-47-eb316385654a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Kill'] =x
#                 Id         groupId         matchId  assists  boosts  \
# 0   2f262dd9795e60  78437bcd91d40e  d5db3a49eb2955        0       0
# 1   a32847cf5bf34b  85b7ce5a12e10b  65223f05c7fdb4        0       0
# 2   1b1900a9990396  edf80d6523380a  1cadec4534f30a        0       3
# 3   f589dd03b60bf2  804ab5e5585558  c4a5676dc91604        0       0
# 4   c23c4cc5b78b35  b3e2cd169ed920  cd595700a01bfa        0       0
# 5   fd034582dd4d2e  9b8930aeee086a  6f6e52b15ddf21        0       1
# 6   c60b5633f4dcc8  7c0f817f6627c7  3232c1e0fec04b        0       3
# 7   f0ba8246b6980f  7318b5204462cb  112e9711f86001        0       0
# ...

# %% [markdown]
# # Q21:-

# %%
data1['winPlacePerc'] = round (data1['winPlacePerc'],2)
data1
# Out:
# <ipython-input-57-7083c630c4ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['winPlacePerc'] = round (data1['winPlacePerc'],2)
#                 Id         groupId         matchId  assists  boosts  \
# 0   2f262dd9795e60  78437bcd91d40e  d5db3a49eb2955        0       0
# 1   a32847cf5bf34b  85b7ce5a12e10b  65223f05c7fdb4        0       0
# 2   1b1900a9990396  edf80d6523380a  1cadec4534f30a        0       3
# 3   f589dd03b60bf2  804ab5e5585558  c4a5676dc91604        0       0
# 4   c23c4cc5b78b35  b3e2cd169ed920  cd595700a01bfa        0       0
# 5   fd034582dd4d2e  9b8930aeee086a  6f6e52b15ddf21        0       1
# 6   c60b5633f4dcc8  7c0f817f6627c7  3232c1e0fec04b        0       3
# ...

# %% [markdown]
# # Q22 :-

# %%
for i in range(100):
    l=[data1.damageDealt]
    
sns.distplot(l)
